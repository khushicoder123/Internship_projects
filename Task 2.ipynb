# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv("/content/gdrive/MyDrive/cleaned_data.csv")

# %%
data.head(15)#to see pattern in data
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             3         1       3
# 2             4         1       1
# 3             5         0       3
# 4             6         0       3
# 5             7         0       1
# 6             9         1       3
# 7            10         1       2
# 8            11         1       3
# 9            13         0       3
# 10           14         0       3
# 11           15         0       3
# 12           18         1       2
# 13           19         0       3
# 14           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1                              Heikkinen, Miss. Laina  female  26.0      0
# 2        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 3                            Allen, Mr. William Henry    male  35.0      0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 718 entries, 0 to 717
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  718 non-null    int64
#  1   Survived     718 non-null    int64
#  2   Pclass       718 non-null    int64
#  3   Name         718 non-null    object
#  4   Sex          718 non-null    object
#  5   Age          718 non-null    float64
#  6   SibSp        718 non-null    int64
#  7   Parch        718 non-null    int64
#  8   Ticket       718 non-null    object
#  9   Fare         718 non-null    float64
#  10  Embarked     718 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 61.8+ KB

# %%
numeric_columns=['Age','Fare']#columns for which stats can be calculated

# %%
from scipy import stats

# %%
for col in numeric_columns:
  print(f"Summary Statistics for {col}:")
  print(f"Mean:{data[col].mean()}")
  print(f"Median:{data[col].median()}")
  print(f"Mode: {data[col].mode()[0]}")
  print(f"Standard Deviation:{data[col].std()}")
  print("\n")
# Out:
# Summary Statistics for Age:
# Mean:28.079387186629525
# Median:28.0
# Mode: 28.0
# Standard Deviation:10.01236856643464
#
#
# Summary Statistics for Fare:
# Mean:17.193203760445684
# Median:11.75
# Mode: 8.05
# Standard Deviation:13.244507195747774

# %%
data[numeric_columns].describe()
# Out:
#               Age        Fare
# count  718.000000  718.000000
# mean    28.079387   17.193204
# std     10.012369   13.244507
# min      3.000000    0.000000
# 25%     22.000000    7.889575
# 50%     28.000000   11.750000
# 75%     32.875000   25.928150
# max     54.000000   61.379200
